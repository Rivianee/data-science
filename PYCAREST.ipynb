# %% [markdown]
# <a href="https://colab.research.google.com/github/Rivianee/data-science/blob/master/PYCAREST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pycaret

# %%
import pandas as pd
from pycaret.classification import *

class CategoryClassifier:
    def __init__(self, file_path):
        self.data = pd.read_excel(file_path)
        self.data['Produto'] = self.data['Produto'].str.lower()
        self.setup_done = False
        self.trained_model = None

    def preprocess_data(self):
        self.data = self.data.dropna(subset=['Produto'])
        if self.data['Categoria'].isnull().any():
            self.data['Categoria'].fillna('Desconhecida', inplace=True)

    def setup_pycaret(self):
        self.exp_clf = setup(data=self.data, target='Categoria', text_features=['Produto'], session_id=123)
        self.setup_done = True

    def train_best_model(self):
        if not self.setup_done:
            print("You need to call setup_pycaret() before training.")
            return
        best_model = compare_models()
        self.trained_model = finalize_model(best_model)

    def classify_uncategorized(self, output_file='seu_arquivo_atualizado.xlsx'):
        if self.trained_model is None:
            print("You need to train a model before classifying.")
            return
        unclassified_data = self.data[self.data['Categoria'].isnull()]
        if len(unclassified_data) > 0:
            predictions = predict_model(self.trained_model, data=unclassified_data)
            self.data.loc[predictions.index, 'Categoria'] = predictions['Label']
            self.data.to_excel(output_file, index=False)
        else:
            print("No items without category to classify.")

# Criar uma instância da classe
classifier = CategoryClassifier('/content/PRODUTO E CATEGORIA PARA TESTE.xlsx')

# Pré-processar os dados
classifier.preprocess_data()

# Configurar o ambiente do PyCaret
classifier.setup_pycaret()

# Comparar modelos e treinar o melhor
classifier.train_best_model()

# Classificar itens sem categoria
classifier.classify_uncategorized()
# Out:
# <style type="text/css">
# #T_821ee_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_821ee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_821ee_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_821ee_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_821ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_821ee_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_821ee_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_821ee_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_821ee_row1_col1" class="data row1 col1" >Categoria</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_821ee_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_821ee_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_821ee_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_821ee_row3_col1" class="data row3 col1" >Açai : 0, Bebida: 1, Carnes: 2, Comida Brasileira: 3, Comida Italiana: 4, Comida Japonesa: 5, Comida Saudável: 6, Comida de outros países: 7, Desconhecida: 8, Lanches: 9, Pizzas: 10, Salgados: 11, Sobremesas e Doces: 12, Árabe: 13</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_821ee_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_821ee_row4_col1" class="data row4 col1" >(4638, 2)</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_821ee_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_821ee_row5_col1" class="data row5 col1" >(4638, 2063)</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_821ee_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_821ee_row6_col1" class="data row6 col1" >(3246, 2063)</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_821ee_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_821ee_row7_col1" class="data row7 col1" >(1392, 2063)</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_821ee_row8_col0" class="data row8 col0" >Text features</td>
#       <td id="T_821ee_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_821ee_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_821ee_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_821ee_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_821ee_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_821ee_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_821ee_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_821ee_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_821ee_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_821ee_row13_col0" class="data row13 col0" >Text features embedding method</td>
#       <td id="T_821ee_row13_col1" class="data row13 col1" >tf-idf</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_821ee_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_821ee_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_821ee_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_821ee_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_821ee_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_821ee_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_821ee_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_821ee_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_821ee_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_821ee_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_821ee_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_821ee_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_821ee_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_821ee_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_821ee_row20_col1" class="data row20 col1" >400c</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                
row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_fe72f_row4_col1" class="data row4 col1" >0.6559</td>
#       <td id="T_fe72f_row4_col2" class="data row4 col2" >0.1008</td>
#       <td id="T_fe72f_row4_col3" class="data row4 col3" >0.6559</td>
#       <td id="T_fe72f_row4_col4" class="data row4 col4" >0.4624</td>
#       <td id="T_fe72f_row4_col5" class="data row4 col5" >0.5368</td>
#       <td id="T_fe72f_row4_col6" class="data row4 col6" >0.0425</td>
#       <td id="T_fe72f_row4_col7" class="data row4 col7" >0.0717</td>
#       <td id="T_fe72f_row4_col8" class="data row4 col8" >0.4300</td>
#     </tr>
#     <tr>
#       <th id="T_fe72f_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_fe72f_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_fe72f_row5_col1" class="data row5 col1" >0.6522</td>
#       <td id="T_fe72f_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_fe72f_row5_col3" class="data row5 col3" >0.6522</td>
#       <td id="T_fe72f_row5_col4" class="data row5 col4" >0.6167</td>
#       <td id="T_fe72f_row5_col5" class="data row5 col5" >0.6237</td>
#       <td id="T_fe72f_row5_col6" class="data row5 col6" >0.2827</td>
#       <td id="T_fe72f_row5_col7" class="data row5 col7" >0.2909</td>
#       <td id="T_fe72f_row5_col8" class="data row5 col8" >0.2310</td>
#     </tr>
#     <tr>
#       <th id="T_fe72f_level0_row6" class="row_heading level0 row6" >et</th>
#       <td id="T_fe72f_row6_col0" class="data row6 col0" >Extra Trees Classifier</td>
#       <td id="T_fe72f_row6_col1" class="data row6 col1" >0.6485</td>
#       <td id="T_fe72f_row6_col2" class="data row6 col2" >0.1482</td>
#       <td id="T_fe72f_row6_col3" class="data row6 col3" >0.6485</td>
#       <td id="T_fe72f_row6_col4" class="data row6 col4" >0.6019</td>
#       <td id="T_fe72f_row6_col5" class="data row6 col5" >0.6136</td>
#       <td id="T_fe72f_row6_col6" class="data row6 col6" >0.2565</td>
#       <td id="T_fe72f_row6_col7" class="data row6 col7" >0.2675</td>
#       <td id="T_fe72f_row6_col8" cla
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]
# <style type="text/css">
# #T_534ec th {
#   text-align: left;
# }
# #T_534ec_row0_col0, #T_534ec_row0_col4, #T_534ec_row0_col5, #T_534ec_row0_col6, #T_534ec_row0_col7, #T_534ec_row1_col0, #T_534ec_row1_col1, #T_534ec_row1_col2, #T_534ec_row1_col3, #T_534ec_row1_col6, #T_534ec_row1_col7, #T_534ec_row2_col0, #T_534ec_row2_col1, #T_534ec_row2_col2, #T_534ec_row2_col3, #T_534ec_row2_col4, #T_534ec_row2_col5, #T_534ec_row2_col6, #T_534ec_row2_col7, #T_534ec_row3_col0, #T_534ec_row3_col1, #T_534ec_row3_col2, #T_534ec_row3_col3, #T_534ec_row3_col4, #T_534ec_row3_col5, #T_534ec_row3_col6, #T_534ec_row3_col7, #T_534ec_row4_col0, #T_534ec_row4_col1, #T_534ec_row4_col2, #T_534ec_row4_col3, #T_534ec_row4_col4, #T_534ec_row4_col5, #T_534ec_row4_col6, #T_534ec_row4_col7, #T_534ec_row5_col0, #T_534ec_row5_col1, #T_534ec_row5_col2, #T_534ec_row5_col3, #T_534ec_row5_col4, #T_534ec_row5_col5, #T_534ec_row5_col6, #T_534ec_row5_col7, #T_534ec_row6_col0, #T_534ec_row6_col1, #T_534ec_row6_col2, #T_534ec_row6_col3, #T_534ec_row6_col4, #T_534ec_row6_col5, #T_534ec_row6_col6, #T_534ec_row6_col7, #T_534ec_row7_col0, #T_534ec_row7_col1, #T_534ec_row7_col2, #T_534ec_row7_col3, #T_534ec_row7_col4, #T_534ec_row7_col5, #T_534ec_row8_col0, #T_534ec_row8_col1, #T_534ec_row8_col2, #T_534ec_row8_col3, #T_534ec_row8_col4, #T_534ec_row8_col5, #T_534ec_row8_col6, #T_534ec_row8_col7, #T_534ec_row9_col0, #T_534ec_row9_col1, #T_534ec_row9_col2, #T_534ec_row9_col3, #T_534ec_row9_col4, #T_534ec_row9_col5, #T_534ec_row9_col6, #T_534ec_row9_col7, #T_534ec_row10_col0, #T_534ec_row10_col1, #T_534ec_row10_col2, #T_534ec_row10_col3, #T_534ec_row10_col4, #T_534ec_row10_col5, #T_534ec_row10_col6, #T_534ec_row10_col7, #T_534ec_row11_col0, #T_534ec_row11_col1, #T_534ec_row11_col2, #T_534ec_row11_col3, #T_534ec_row11_col4, #T_534ec_row11_col5, #T_534ec_row11_col6, #T_534ec_row11_col7, #T_534ec_row12_col0, #T_534ec_row12_col1, #T_534ec_row12_col2, #T_534ec_row12_col3, #T_534ec_row12_col4, #T_534ec_row12_col5, #T_534ec_row12_col6, #T_534ec_row12_col7, #T_534ec_row13_col0, #T_534ec_row13_col1, #T_534ec_row13_col2, #T_534ec_row13_col3, #T_534ec_row13_col4, #T_534ec_row13_col5, #T_534ec_row13_col6, #T_534ec_row13_col7 {
#   text-align: left;
# }
# #T_534ec_row0_col1, #T_534ec_row0_col2, #T_534ec_row0_col3, #T_534ec_row1_col4, #T_534ec_row1_col5, #T_534ec_row7_col6, #T_534ec_row7_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_534ec_row0_col8, #T_534ec_row1_col8, #T_534ec_row2_col8, #T_534ec_row3_col8, #T_534ec_row4_col8, #T_534ec_row5_col8, #T_534ec_row6_col8, #T_534ec_row8_col8, #T_534ec_row9_col8, #T_534ec_row10_col8, #T_534ec_row11_col8, #T_534ec_row12_col8, #T_534ec_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_534ec_row7_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_534ec" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_534ec_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_534ec_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_534ec_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_534ec_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_534ec_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_534ec_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_534ec_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_534ec_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_534ec_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_534ec_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_534ec_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_534ec_row0_col1" class="data row0 col1" >0.6790</td>
#       <td id="T_534ec_row0_col2" class="data row0 col2" >0.1540</td>
#       <td id="T_534ec_row0_col3" class="data row0 col3" >0.6790</td>
#       <td id="T_534ec_row0_col4" class="data row0 col4" >0.6039</td>
#       <td id="T_534ec_row0_col5" class="data row0 col5" >0.5865</td>
#       <td id="T_534ec_row0_col6" class="data row0 col6" >0.1496</td>
#       <td id="T_534ec_row0_col7" class="data row0 col7" >0.2262</td>
#       <td id="T_534ec_row0_col8" class="data row0 col8" >1.1020</td>
#     </tr>
#     <tr>
#       <th id="T_534ec_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_534ec_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_534ec_row1_col1" class="data row1 col1" >0.6750</td>
#       <td id="T_534ec_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_534ec_row1_col3" class="data row1 col3" >0.6750</td>
#       <td id="T_534ec_row1_col4" class="data row1 col4" >0.6257</td>
#       <td id="T_534ec_row1_col5" class="data row1 col5" >0.6258</td>
#       <td id="T_534ec_row1_col6" class="data row1 col6" >0.2622</td>
#       <td id="T_534ec_row1_col7" class="data row1 col7" >0.2877</td>
#       <td id="T_534ec_row1_col8" class="data row1 col8" >0.3470</td>
#     </tr>
#     <tr>
#       <th id="T_534ec_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_534ec_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_534ec_row2_col1" class="data row2 col1" >0.6651</td>
#       <td id="T_534ec_row2_col2" class="data row2 col2" >0.1403</td>
#       <td id="T_534ec_row2_col3" class="data row2 col3" >0.6651</td>
#       <td id="T_534ec_row2_col4" class="data row2 col4" >0.5950</td>
#       <td id="T_534ec_row2_col5" class="data row2 col5" >0.5988</td>
#       <td id="T_534ec_row2_col6" class="data row2 col6" >0.1935</td>
#       <td id="T_534ec_row2_col7" class="data row2 col7" >0.2271</td>
#       <td id="T_534ec_row2_col8" class="data row2 col8" >0.7500</td>
#     </tr>
#     <tr>
#       <th id="T_534ec_level0_row3" class="row_heading level0 row3" >dummy</th>
#       <td id="T_534ec_row3_col0" class="data row3 col0" >Dummy Classifier</td>
#       <td id="T_534ec_row3_col1" class="data row3 col1" >0.6583</td>
#       <td id="T_534ec_row3_col2" class="data row3 col2" >0.1000</td>
#       <td id="T_534ec_row3_col3" class="data row3 col3" >0.6583</td>
#       <td id="T_534ec_row3_col4" class="data row3 col4" >0.4334</td>
#       <td id="T_534ec_row3_col5" class="data row3 col5" >0.5227</td>
#       <td id="T_534ec_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_534ec_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_534ec_row3_col8" class="data row3 col8" >0.3150</td>
#     </tr>
#     <tr>
#       <th id="T_534ec_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_534ec_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_534ec_row4_col1" class="data row4 col1" >0.6580</td>
#       <td id="T_534ec_row4_col2" class="data row4 col2" >0.1458</td>
#       <td id="T_534ec_row4_col3" class="data row4 col3" >0.6580</td>
#       <td id="T_534ec_row4_col4" class="data row4 col4" >0.5952</td>
#       <td id="T_534ec_row4_col5" class="data row4 col5" >0.6089</td>
#       <td id="T_534ec_row4_col6" class="data row4 col6" >0.2368</td>
#       <td id="T_534ec_row4_col7" class="data row4 col7" >0.2569</td>
#       <td id="T_534ec_row4_col8" class="data row4 col8" >172.6200</td>
#     </tr>
#     <tr>
#       <th id="T_534ec_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_534ec_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_534ec_row5_col1" class="data row5 col1" >0.6565</td>
#       <td id="T_534ec_row5_col2" class="data row5 col2" >0.1480</td>
#       <td id="T_534ec_row5_col3" class="data row5 col3" >0.6565</td>
#       <td id="T_534ec_row5_col4" class="data row5 col4" >0.5941</td>
#       <td id="T_534ec_row5_col5" class="data row5 col5" >0.6047</td>
#       <td id="T_534ec_row5_col6" class="data row5 col6" >0.2201</td>
#       <td id="T_534ec_row5_col7" class="data row5 col7" >0.2421</td>
# No items without category to classify.
